# %%
import pandas as pd
import json as js

# %%
LA_traffic_collision = "traffic-collision-data-from-2010-to-present.csv"

LA_traffic = pd.read_csv(LA_traffic_collision)
LA_traffic.dropna(inplace = True)
LA_traffic.head()
# Out:
#      DR Number            Date Reported            Date Occurred  \
# 63   190317457  2019-07-25T00:00:00.000  2019-07-25T00:00:00.000
# 95   191816503  2019-07-25T00:00:00.000  2019-07-25T00:00:00.000
# 167  190513112  2019-07-24T00:00:00.000  2019-07-24T00:00:00.000
# 172  191218985  2019-07-25T00:00:00.000  2019-07-24T00:00:00.000
# 175  191218996  2019-07-25T00:00:00.000  2019-07-24T00:00:00.000
#
#      Time Occurred  Area ID    Area Name  Reporting District  Crime Code  \
# 63            1810        3    Southwest                 328         997
# 95             828       18    Southeast                1841         997
# 167           2145        5       Harbor                 587         997
# 172           2130       12  77th Street                1209         997
# 175           1745       12  77th Street                1265         997
#
#     Crime Code Description                       MO Codes  ...  \
# 63       TRAFFIC COLLISION  4025 3037 3004 3028 3030 3101  ...
# ...

# %%
LA_traffic.drop(['Premise Description', 'Zip Codes', 'Census Tracts', 'Precinct Boundaries', 'LA Specific Plans', 'Council Districts', 'Neighborhood Councils (Certified)', 'Victim Age', 'Victim Sex', 'Victim Descent', 'Premise Code', 'Time Occurred', 'Area ID', 'Reporting District', 'Crime Code', 'MO Codes', 'Address', 'Cross Street', 'Location'], axis=1, inplace=True)
LA_traffic.head()
# Out:
#      DR Number            Date Reported            Date Occurred    Area Name  \
# 63   190317457  2019-07-25T00:00:00.000  2019-07-25T00:00:00.000    Southwest
# 95   191816503  2019-07-25T00:00:00.000  2019-07-25T00:00:00.000    Southeast
# 167  190513112  2019-07-24T00:00:00.000  2019-07-24T00:00:00.000       Harbor
# 172  191218985  2019-07-25T00:00:00.000  2019-07-24T00:00:00.000  77th Street
# 175  191218996  2019-07-25T00:00:00.000  2019-07-24T00:00:00.000  77th Street
#
#     Crime Code Description
# 63       TRAFFIC COLLISION
# 95       TRAFFIC COLLISION
# 167      TRAFFIC COLLISION
# 172      TRAFFIC COLLISION
# 175      TRAFFIC COLLISION

# %%
LA_data_load = "Crime_Data_2010_2017.csv"
LA_crime = pd.read_csv(LA_data_load)
LA_crime.dropna(inplace=True)
LA_crime.head()
# Out:
#         DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 15370   130222023    11/12/2013    11/11/2013           2330        2
# 29137   130404327    01/09/2013    01/08/2013           1130        4
# 98680   101200908    09/23/2010    09/23/2010           1350       12
# 98711   101200992    11/04/2010    10/31/2010           2300       12
# 225210  100307604    02/24/2010    02/23/2010           2000        3
#
#           Area Name  Reporting District  Crime Code Crime Code Description  \
# 15370       Rampart                 265         121         RAPE, FORCIBLE
# 29137    Hollenbeck                 497         210                ROBBERY
# 98680   77th Street                1209         121         RAPE, FORCIBLE
# 98711   77th Street                1258         121         RAPE, FORCIBLE
# 225210    Southwest                 395         121         RAPE, FORCIBLE
#
#                                                  MO Codes  ...  \
# ...

# %%
LA_crime.drop(['Weapon Description', 'Status Code', 'Status Description', 'Crime Code 1', 'Crime Code 2', 'Crime Code 3', 'Crime Code 4', 'Victim Age', 'Victim Sex', 'Premise Code', 'Premise Description', 'Weapon Used Code', 'Victim Descent', 'Time Occurred', 'Area ID', 'Reporting District', 'Crime Code', 'MO Codes', 'Address', 'Cross Street'], axis=1, inplace=True)
LA_crime.head()
# Out:
#         DR Number Date Reported Date Occurred    Area Name  \
# 15370   130222023    11/12/2013    11/11/2013      Rampart
# 29137   130404327    01/09/2013    01/08/2013   Hollenbeck
# 98680   101200908    09/23/2010    09/23/2010  77th Street
# 98711   101200992    11/04/2010    10/31/2010  77th Street
# 225210  100307604    02/24/2010    02/23/2010    Southwest
#
#        Crime Code Description             Location
# 15370          RAPE, FORCIBLE  (34.0549, -118.2778)
# 29137                 ROBBERY  (34.0243, -118.2198)
# 98680          RAPE, FORCIBLE  (34.0011, -118.2827)
# 98711          RAPE, FORCIBLE  (33.9697, -118.2695)
# 225210         RAPE, FORCIBLE  (34.0073, -118.3089)

# %%
LA_crime.to_csv(r'C:\Users\bchik\Desktop\ETL\Data/LA_crime.csv', index=False)

# %%
LA_traffic.to_csv(r'C:\Users\bchik\Desktop\ETL\Data/LA_traffic.csv', index=False)

# %%
#import psycopg2

# %%
#conn = psycopg2.connect("host=localhost dbname=ETL user=postgres password=postgres")
